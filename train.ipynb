# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    pass
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML-project-20212
# Out:
# /content/drive/.shortcut-targets-by-id/15ssB9QEPzR4LVAvGtMtKshsNHWfwV518/ML-project-20212

# %%
# !ls
# Out:
# checkpoints  data  notebooks  note.txt	README.md  scripts  train.ipynb

# %%
# !python3 scripts/main.py --model lgr --name ranforest -ne 10 -bs 512 --data "./data/elite.csv" -es 200
# Out:
# param = {'batch_size': 512, 'data': './data/elite.csv', 'epochs': 10, 'model': 'lgr', 'n_estimators': 100, 'name': 'third'}
# features.shape = (1343380, 78)
# labels.shape   = (1343380,)
# X_train.shape = (1074704, 78)
# X_test.shape  = (268676, 78)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
#
# train_score =
# Train Result:
# ...
# Accuracy Score: 86.63%
# _______________________________________________
# CLASSIFICATION REPORT:
#                        0  ...  weighted avg
# ...
