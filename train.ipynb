# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    pass
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML-project-20212
# Out:
# /content/drive/.shortcut-targets-by-id/15ssB9QEPzR4LVAvGtMtKshsNHWfwV518/ML-project-20212

# %%
# !ls
# Out:
# checkpoints  data  notebooks  note.txt	README.md  scripts  train.ipynb

# %%
# !python3 scripts/main.py --model rdf --name second -ne 10 -bs 512 --data ./data/elite.csv
# Out:
# param = {'batch_size': 512, 'data': './data/elite.csv', 'epochs': 10, 'model': 'rdf', 'name': 'second'}
# features.shape = (1343380, 78)
# labels.shape   = (1343380,)
# X_train.shape = (1074704, 78)
# X_test.shape  = (268676, 78)
# train_score =
# Train Result:
# ...
# Accuracy Score: 100.00%
# _______________________________________________
# CLASSIFICATION REPORT:
#                        0  ...  weighted avg
# precision       0.999995  ...  9.999972e-01
# recall          0.999991  ...  9.999972e-01
# f1-score        0.999993  ...  9.999972e-01
# support    214732.000000  ...  1.074704e+06
#
# [4 rows x 5 columns]
# _______________________________________________
# Confusion Matrix:
#  [[214730      2]
#  [     1 859971]]
#
# test_score =
# Test Result:
# ...
# Accuracy Score: 88.82%
# _______________________________________________
# CLASSIFICATION REPORT:
#                       0  ...   weighted avg
# precision      0.759814  ...       0.883435
# recall         0.640889  ...       0.888241
# ...
